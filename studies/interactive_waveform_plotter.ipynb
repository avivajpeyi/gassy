# %%
# %load_ext autoreload
# %load_ext jupyternotify
# %autoreload 2
# %matplotlib inlines

# %%
import ipywidgets as widgets
from gassy.two_body import WaveformGenerator
from IPython.display import display


def make_plot(m=1, M=10, r=-1, num_periods=10, drag_coeff=1e20):
    kwgs = dict(m=m, M=M,  r=r, num_periods=num_periods, drag_coeff=drag_coeff)
    return WaveformGenerator.from_evol_inital_conditions(**kwgs).plot(distance=1000)



make_plot()
# Out:
# /Users/avaj0001/Documents/projects/gassy/venv/lib/python3.9/site-packages/scipy/integrate/_odepack_py.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /Users/avaj0001/Documents/projects/gassy/gassy/two_body/systems/two_body_base.py:154: RuntimeWarning: divide by zero encountered in double_scalars
#   return -G * self.m * self.Me / self.rmag
# /Users/avaj0001/Documents/projects/gassy/gassy/two_body/systems/two_body_base.py:78: RuntimeWarning: divide by zero encountered in double_scalars
#   f_mag = -G * self.m * self.M / self.rmag**2
# /Users/avaj0001/Documents/projects/gassy/gassy/two_body/systems/two_body_base.py:49: RuntimeWarning: invalid value encountered in divide
#   return self.r / self.rmag
# /Users/avaj0001/Documents/projects/gassy/gassy/two_body/systems/two_body_base.py:57: RuntimeWarning: invalid value encountered in divide
# ...

# %%
def make_interactive_plot(r, drag_coeff):
    make_plot(r=r, drag_coeff=drag_coeff)

r_slider = widgets.FloatSlider(min=-5, max=5, step=0.1, value=-1, continuous_update=False)
drag_slider = widgets.FloatLogSlider(min=-3, max=-1, value=-2,continuous_update=False)
l = widgets.Layout(min_height='50px', width='100px')
w=widgets.interactive(make_interactive_plot,r=r_slider, drag_coeff=drag_slider, layout=l)
w
# Out:
# interactive(children=(FloatSlider(value=-1.0, continuous_update=False, description='r', max=5.0, min=-5.0), Fl…
